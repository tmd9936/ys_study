# %%
from selenium import webdriver as wd

# 아래 3개의 모듈을 한 묶음으로 많이 사용
# (기대조건이 될 때까지 기다리겠다는 의미로 활용)
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait # 웹페이지기동 전 대기시간
from selenium.webdriver.support import expected_conditions as EC

from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

chrome_options = Options()

# Headless 모드 : 브라우저를 안 띄우고 사용하는 모드
chrome_options.add_argument('--headless')

# webdriver 설정(Chrome, Firefox...) - Headless 모드로 설정됨
browser = wd.Chrome('./webdriver/chromedriver.exe', options=chrome_options)

# 일반모드(브라우저 띄움)
# browser = wd.Chrome('./webdriver/chromedriver.exe')

# 브라우저 내부 대기시간
# 랜더링하는 5초안에 브라우저가 안 띄워지면 에러발생
browser.implicitly_wait(5)

# 브라우저 사이즈
browser.set_window_size(1280, 720)

# 페이지 이동
browser.get('http://prod.danawa.com/list/?cate=112758&15main_11_02')

# 페이지 내용 확인하기
# print(f'page content : {browser.page_source}')

# 로딩이 될 때 까지 기다린 후 선택
# 더보기 클릭하기
WebDriverWait(browser, 3).until(EC.presence_of_element_located((By.XPATH, \
                '//*[@id="dlMaker_simple"]/dd/div[2]/button[1]'))).click()

# 원하는 상품 클릭하기
WebDriverWait(browser, 4).until(EC.presence_of_element_located((By.XPATH, \
                '//*[@id="searchMaker1452"]'))).click()

time.sleep(3)

# 현재 페이지
cur_page = 1

# 크롤링 할 페이지 수 )
target_page = 3

while cur_page <= target_page:
    
    # bs4 초기화
    bs = BeautifulSoup(browser.page_source, 'lxml')

    # 소스코드 정리해서 보기
    # print(bs.prettify)
    
    # 페이지 번호 출력
    print(f'******** Page : {cur_page} *******')
    print()

    prod_list = bs.select('div.main_prodlist.main_prodlist_list > ul > li')

    # print(prod_list)

    # 원하는 정보 추출
    for li in prod_list:
        if not li.find('div', class_='ad_caster'):
            print(li.select('p.prod_name > a')[0].text.strip())
            print(li.select('p.price_sect > a')[0].text.strip())

            img_data = li.select('a.thumb_link > img')[0].get('data-original')
            img_src = li.select('a.thumb_link > img')[0]['src']

            print(img_data if img_data else img_src)
        print()
    print()
    
    cur_page += 1
    
    if cur_page > target_page:
        print('크롤링 성공')
        break
    
    # 페이지 클릭
    WebDriverWait(browser, 3).until(EC.presence_of_element_located((By.CSS_SELECTOR , \
                f'div.number_wrap > a:nth-child({cur_page})'))).click()
    
    # 2초간 대기
    time.sleep(2)

browser.quit()
# Out:
# ******** Page : 1 *******
#
# APPLE 2019 맥북프로16 MVVK2KH/A
# 2,929,000원
# http://img.danawa.com/prod_img/500000/439/911/img/9911439_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2020 맥북프로13 MXK32KH/A
# 1,599,000원
# http://img.danawa.com/prod_img/500000/225/217/img/11217225_1.jpg?shrink=160:160&_v=20200716140310
#
# APPLE 2019 맥북프로16 MVVL2KH/A
# 2,641,000원
# http://img.danawa.com/prod_img/500000/160/911/img/9911160_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2019 맥북프로16 MVVJ2KH/A
# 2,722,000원
# http://img.danawa.com/prod_img/500000/355/911/img/9911355_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2020 맥북프로13 MWP42KH/A
# 2,297,000원
# http://img.danawa.com/prod_img/500000/507/217/img/11217507_1.jpg?shrink=160:160&_v=20200716140430
#
# APPLE 2019 맥북프로16 MVVJ2KH/A CTO
# 2,688,000원
# http://img.danawa.com/prod_img/500000/940/941/img/9941940_1.jpg?shrink=160:160&_v=20200702161743
#
# APPLE 2020 맥북에어 MVH22KH/A CTO
# 1,493,000원
# http://img.danawa.com/prod_img/500000/726/914/img/10914726_1.jpg?shrink=160:160&_v=20200331160157
#
# APPLE 2020 맥북에어 MVH22KH/A
# 1,419,000원
# http://img.danawa.com/prod_img/500000/123/872/img/10872123_1.jpg?shrink=160:160&_v=20200507141925
#
# APPLE 2020 맥북에어 MWTJ2KH/A
# 1,154,000원
# http://img.danawa.com/prod_img/500000/238/871/img/10871238_1.jpg?shrink=160:160&_v=20200423124839
#
# APPLE 2019 맥북프로16 MVVM2KH/A
# 3,011,000원
# http://img.danawa.com/prod_img/500000/418/911/img/9911418_1.jpg?shrink=160:160&_v=20200319131535
#
#
# APPLE 2019 맥북프로13 MV992KH/A
# 1,698,000원
# http://img.danawa.com/prod_img/500000/100/106/img/8106100_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2020 맥북프로13 MWP52KH/A
# 2,462,000원
# http://img.danawa.com/prod_img/500000/570/217/img/11217570_1.jpg?shrink=160:160&_v=20200716140510
#
# APPLE 2020 맥북에어 MVH52KH/A
# 1,451,000원
# http://img.danawa.com/prod_img/500000/507/872/img/10872507_1.jpg?shrink=160:160&_v=20200325105411
#
# APPLE 2020 맥북에어 MWTL2KH/A
# 1,138,000원
# http://img.danawa.com/prod_img/500000/259/871/img/10871259_1.jpg?shrink=160:160&_v=20200618100747
#
# APPLE 2017 맥북프로13 MPXT2KH/A
# 1,216,010원
# http://img.danawa.com/prod_img/500000/944/250/img/5250944_1.jpg?shrink=160:160&_v=20200319130752
#
# APPLE 2020 맥북에어 MWTK2KH/A
# 1,161,000원
# http://img.danawa.com/prod_img/500000/274/871/img/10871274_1.jpg?shrink=160:160&_v=20200325105217
#
# APPLE 2019 맥북프로13 MUHN2KH/A
# 1,446,000원
# http://img.danawa.com/prod_img/500000/734/919/img/8919734_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2020 맥북에어 MVH42KH/A
# 1,410,000원
# http://img.danawa.com/prod_img/500000/519/872/img/10872519_1.jpg?shrink=160:160&_v=20200402135746
#
# APPLE 2018 맥북에어 MREF2KH/A
# 1,042,410원
# http://img.danawa.com/prod_img/500000/593/698/img/6698593_1.jpg?shrink=160:160&_v=20200319131125
#
# APPLE 2018 맥북프로13 MR9V2KH/A
# 1,512,110원
# http://img.danawa.com/prod_img/500000/093/365/img/6365093_1.jpg?shrink=160:160&_v=20200319131017
#
#
# APPLE 2020 맥북프로13 MWP72KH/A
# 2,296,000원
# http://img.danawa.com/prod_img/500000/534/217/img/11217534_1.jpg?shrink=160:160&_v=20200716140204
#
# APPLE 2019 맥북프로13 MV962KH/A
# 1,990,000원
# http://img.danawa.com/prod_img/500000/037/106/img/8106037_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2019 맥북프로13 MV972KH/A
# 1,838,000원
# http://img.danawa.com/prod_img/500000/343/106/img/8106343_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2019 맥북프로13 MUHP2KH/A
# 1,504,000원
# http://img.danawa.com/prod_img/500000/342/921/img/8921342_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2020 맥북프로13 MWP72KH/A CTO
# 2,308,270원
# http://img.danawa.com/prod_img/500000/075/448/img/11448075_1.jpg?shrink=160:160&_v=20200608125336
#
# APPLE 2019 맥북프로13 MV9A2KH/A
# 1,838,000원
# http://img.danawa.com/prod_img/500000/388/106/img/8106388_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2020 맥북프로13 MXK62KH/A
# 1,580,000원
# http://img.danawa.com/prod_img/500000/336/217/img/11217336_1.jpg?shrink=160:160&_v=20200716140054
#
# APPLE 2019 맥북에어 MVFL2KH/A
# 1,156,110원
# http://img.danawa.com/prod_img/500000/690/918/img/8918690_1.jpg?shrink=160:160&_v=20200319131210
#
# APPLE 2017 맥북프로15 MPTT2KH/A
# 2,550,000원
# http://img.danawa.com/prod_img/500000/141/250/img/5250141_1.jpg?shrink=160:160&_v=20200319094756
#
# APPLE 2020 맥북프로13 MXK52KH/A
# 1,810,000원
# http://img.danawa.com/prod_img/500000/411/217/img/11217411_1.jpg?shrink=160:160&_v=20200716140347
#
#
# ******** Page : 2 *******
#
# APPLE 2019 맥북프로15 MV932KH/A
# 2,699,000원
# http://img.danawa.com/prod_img/500000/235/100/img/8100235_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2020 맥북프로13 MXK72KH/A
# 1,825,000원
# http://img.danawa.com/prod_img/500000/441/217/img/11217441_1.jpg?shrink=160:160&_v=20200716140124
#
# APPLE 2019 맥북프로16 MVVK2KH/A CTO
# 3,114,000원
# http://img.danawa.com/prod_img/500000/964/941/img/9941964_1.jpg?shrink=160:160&_v=20200319131534
#
# APPLE 2020 맥북에어 MVH42KH/A CTO
# 1,493,000원
# http://img.danawa.com/prod_img/500000/669/914/img/10914669_1.jpg?shrink=160:160&_v=20200331160244
#
# APPLE 2019 맥북프로13 MUHQ2KH/A
# 1,413,000원
# http://img.danawa.com/prod_img/500000/904/920/img/8920904_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2020 맥북프로13 MXK32KH/A CTO
# 1,565,100원
# http://img.danawa.com/prod_img/500000/294/448/img/11448294_1.jpg?shrink=160:160&_v=20200608125508
#
# APPLE 2017 맥북프로13 MPXQ2KH/A
# 944,100원
# http://img.danawa.com/prod_img/500000/891/250/img/5250891_1.jpg?shrink=160:160&_v=20200319130753
#
# APPLE 2020 맥북프로13 MWP82KH/A
# 2,474,000원
# http://img.danawa.com/prod_img/500000/585/217/img/11217585_1.jpg?shrink=160:160&_v=20200716140237
#
# APPLE 2019 맥북프로15 MV912KH/A
# 2,699,000원
# http://img.danawa.com/prod_img/500000/319/100/img/8100319_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2019 맥북프로13 MUHR2KH/A
# 1,645,590원
# http://img.danawa.com/prod_img/500000/168/921/img/8921168_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2019 맥북프로15 MV922KH/A
# 2,696,000원
# http://img.danawa.com/prod_img/500000/538/100/img/8100538_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2019 맥북에어 MVFJ2KH/A
# 1,392,000원
# http://img.danawa.com/prod_img/500000/810/918/img/8918810_1.jpg?shrink=160:160&_v=20200319131210
#
# APPLE 2019 맥북프로15 MV902KH/A
# 2,677,000원
# http://img.danawa.com/prod_img/500000/466/100/img/8100466_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2018 맥북프로15 MR942KH/A
# 3,110,000원
# http://img.danawa.com/prod_img/500000/315/365/img/6365315_1.jpg?shrink=160:160&_v=20200319131017
#
# APPLE 2019 맥북에어 MVFK2KH/A
# 1,209,000원
# http://img.danawa.com/prod_img/500000/802/917/img/8917802_1.jpg?shrink=160:160&_v=20200319131210
#
# APPLE 2018 맥북프로13 MR9U2KH/A
# 1,700,000원
# http://img.danawa.com/prod_img/500000/973/364/img/6364973_1.jpg?shrink=160:160&_v=20200319131017
#
# APPLE 2019 맥북에어 MVFH2KH/A
# 1,209,990원
# http://img.danawa.com/prod_img/500000/796/917/img/8917796_1.jpg?shrink=160:160&_v=20200319131210
#
# APPLE 2019 맥북에어 MVFM2KH/A
# 1,210,000원
# http://img.danawa.com/prod_img/500000/790/917/img/8917790_1.jpg?shrink=160:160&_v=20200319131210
#
# APPLE 2018 맥북프로15 MR932KH/A
# 2,660,000원
# http://img.danawa.com/prod_img/500000/617/363/img/6363617_1.jpg?shrink=160:160&_v=20200319131017
#
# APPLE 2019 맥북에어 MVFN2KH/A
# 1,391,000원
# http://img.danawa.com/prod_img/500000/756/918/img/8918756_1.jpg?shrink=160:160&_v=20200319131210
#
# APPLE 2018 맥북에어 MREE2KH/A
# 1,230,000원
# http://img.danawa.com/prod_img/500000/111/610/img/6610111_1.jpg?shrink=160:160&_v=20200319131126
#
# APPLE 2017 맥북프로13 MPXU2KH/A
# 1,169,100원
# http://img.danawa.com/prod_img/500000/938/250/img/5250938_1.jpg?shrink=160:160&_v=20200319130752
#
# APPLE 2020 맥북프로13 MWP42KH/A CTO
# 2,308,270원
# http://img.danawa.com/prod_img/500000/018/448/img/11448018_1.jpg?shrink=160:160&_v=20200608125617
#
# APPLE 2017 맥북프로13 MPXR2KH/A
# 944,100원
# http://img.danawa.com/prod_img/500000/851/250/img/5250851_1.jpg?shrink=160:160&_v=20200319130753
#
# APPLE 2018 맥북에어 MRE92KH/A
# 1,460,000원
# http://img.danawa.com/prod_img/500000/530/698/img/6698530_1.jpg?shrink=160:160&_v=20200319131125
#
# APPLE 2018 맥북프로15 MR972KH/A
# 2,950,000원
# http://img.danawa.com/prod_img/500000/384/365/img/6365384_1.jpg?shrink=160:160&_v=20200319131017
#
# APPLE 2018 맥북프로15 MR962KH/A
# 2,620,000원
# http://img.danawa.com/prod_img/500000/422/364/img/6364422_1.jpg?shrink=160:160&_v=20200319131017
#
# APPLE 2020 맥북에어 MWTL2KH/A CTO
# 1,165,010원
# http://img.danawa.com/prod_img/500000/693/914/img/10914693_1.jpg?shrink=160:160&_v=20200331160104
#
# APPLE 2019 맥북프로16 MVVM2KH/A CTO
# 3,079,000원
# http://img.danawa.com/prod_img/500000/958/941/img/9941958_1.jpg?shrink=160:160&_v=20200319131534
#
# APPLE 2018 맥북프로13 MR9Q2KH/A
# 1,690,000원
# http://img.danawa.com/prod_img/500000/686/364/img/6364686_1.jpg?shrink=160:160&_v=20200319131017
# ******** Page : 3 *******
#
# APPLE 2018 맥북에어 MRE82KH/A
# 1,265,000원
# http://img.danawa.com/prod_img/500000/160/609/img/6609160_1.jpg?shrink=160:160&_v=20200319131126
#
# APPLE 2018 맥북프로13 MR9R2KH/A
# 2,190,000원
# http://img.danawa.com/prod_img/500000/061/365/img/6365061_1.jpg?shrink=160:160&_v=20200319131017
#
# APPLE 2020 맥북프로13 MWP52KH/A CTO
# 2,529,000원
# http://img.danawa.com/prod_img/500000/742/447/img/11447742_1.jpg?shrink=160:160&_v=20200608125652
#
# APPLE 2019 맥북프로16 MVVL2KH/A CTO
# 2,693,000원
# http://img.danawa.com/prod_img/500000/934/941/img/9941934_1.jpg?shrink=160:160&_v=20200319131535
#
# APPLE 2020 맥북프로13 MXK62KH/A CTO
# 1,565,100원
# http://img.danawa.com/prod_img/500000/309/448/img/11448309_1.jpg?shrink=160:160&_v=20200608125214
#
# APPLE 2020 맥북에어 MVH52KH/A CTO
# 1,493,000원
# http://img.danawa.com/prod_img/500000/753/914/img/10914753_1.jpg?shrink=160:160&_v=20200331160018
#
# APPLE 2020 맥북에어 MWTK2KH/A CTO
# 1,178,100원
# http://img.danawa.com/prod_img/500000/153/914/img/10914153_1.jpg?shrink=160:160&_v=20200331160304
#
# APPLE 2018 맥북프로15 MR952KH/A
# 3,189,990원
# http://img.danawa.com/prod_img/500000/743/526/img/9526743_1.jpg?shrink=160:160&_v=20200319131013
#
# APPLE 2020 맥북프로13 MWP82KH/A CTO
# 2,529,000원
# http://img.danawa.com/prod_img/500000/982/447/img/11447982_1.jpg?shrink=160:160&_v=20200608125414
#
# APPLE 2019 맥북프로15 MV952KH/A
# 3,489,000원
# http://img.danawa.com/prod_img/500000/748/811/img/10811748_1.jpg?shrink=160:160&_v=20200319131534
#
# APPLE 2018 맥북에어 MREC2KH/A
# 1,089,990원
# http://img.danawa.com/prod_img/500000/623/698/img/6698623_1.jpg?shrink=160:160&_v=20200319131125
#
# APPLE 2014 맥북프로13 ME864KH/A
# 599,000원
# http://img.danawa.com/prod_img/500000/512/129/img/6129512_1.jpg?shrink=160:160&_v=20200422133313
#
# APPLE 2017 맥북프로15 MPTR2KH/A
# 2,481,590원
# http://img.danawa.com/prod_img/500000/187/250/img/5250187_1.jpg?shrink=160:160&_v=20200319094756
#
# APPLE 2020 맥북에어 MWTJ2KH/A CTO
# 1,178,100원
# http://img.danawa.com/prod_img/500000/099/914/img/10914099_1.jpg?shrink=160:160&_v=20200331160134
#
# APPLE 2020 맥북프로13 MXK52KH/A CTO
# 1,809,000원
# http://img.danawa.com/prod_img/500000/219/448/img/11448219_1.jpg?shrink=160:160&_v=20200608125541
#
# APPLE 2020 맥북프로13 MXK72KH/A CTO
# 1,809,000원
# http://img.danawa.com/prod_img/500000/270/448/img/11448270_1.jpg?shrink=160:160&_v=20200608125254
#
# APPLE 2017 맥북프로13 MPXV2KH/A
# 1,851,790원
# http://img.danawa.com/prod_img/500000/622/250/img/5250622_1.jpg?shrink=160:160&_v=20200319130753
#
# APPLE 2017 맥북프로13 MPXY2KH/A
# 1,853,860원
# http://img.danawa.com/prod_img/500000/742/250/img/5250742_1.jpg?shrink=160:160&_v=20200319130753
#
# APPLE 2017 맥북 MNYF2KH/A
# 1,043,100원
# http://img.danawa.com/prod_img/500000/761/250/img/5250761_1.jpg?shrink=160:160&_v=20200319095457
#
# APPLE 2018 맥북프로15 MUQH2KH/A
# 3,189,990원
# http://img.danawa.com/prod_img/500000/062/810/img/10810062_1.jpg?shrink=160:160&_v=20200326125722
#
# APPLE 2018 맥북에어 MREA2KH/A
# 1,269,000원
# http://img.danawa.com/prod_img/500000/141/610/img/6610141_1.jpg?shrink=160:160&_v=20200319131125
#
# APPLE 2017 맥북 MNYH2KH/A
# 1,043,100원
# http://img.danawa.com/prod_img/500000/866/250/img/5250866_1.jpg?shrink=160:160&_v=20200319095457
#
# APPLE 맥북에어 MC965KH/A
# 854,040원
# http://img.danawa.com/prod_img/500000/567/396/img/3396567_1.jpg?shrink=160:160&_v=20180426141938
#
# APPLE 2017 맥북 MNYG2KH/A
# 1,223,100원
# http://img.danawa.com/prod_img/500000/971/250/img/5250971_1.jpg?shrink=160:160&_v=20200319095457
#
# APPLE 2017 맥북 MNYN2KH/A
# 1,930,000원
# http://img.danawa.com/prod_img/500000/968/250/img/5250968_1.jpg?shrink=160:160&_v=20200319095457
#
# APPLE 2017 맥북프로13 MPXX2KH/A
# 1,851,790원
# http://img.danawa.com/prod_img/500000/374/250/img/5250374_1.jpg?shrink=160:160&_v=20200319130753
#
# APPLE 2016 맥북 MLHF2KH/A
# 1,601,600원
# http://img.danawa.com/prod_img/500000/857/988/img/3988857_1.jpg?shrink=160:160&_v=20200319093922
#
# APPLE 2017 맥북 MNYJ2KH/A
# 1,223,100원
# http://img.danawa.com/prod_img/500000/975/250/img/5250975_1.jpg?shrink=160:160&_v=20200319095457
#
# APPLE 2017 맥북프로15 MPTU2KH/A
# 2,519,190원
# http://img.danawa.com/prod_img/500000/233/250/img/5250233_1.jpg?shrink=160:160&_v=20200319094756
#
# APPLE 2017 맥북프로15 MPTV2KH/A
# 2,550,000원
# http://img.danawa.com/prod_img/500000/037/250/img/5250037_1.jpg?shrink=160:160&_v=20200319094756
#
#
# 크롤링 성공
